# %% [markdown]
# # ¿Cómo mejorar tus tareas escolares sin hacer trampa?

# %% [markdown]
# ## 🚨 ANTES DE EMPEZAR: Tres historias ocurridas en la misma clases el 2025
#
# <div style="text-align:justify;">El docente les solicito a los estudiantes del curso que eligieran un tema de varios entregados por él  y construyeran un informe en el formato que los estudiantes eligiéran (ppt o doc) pero usando una herramienta de IA que ellos eligieran y junto con ello, entregar un análisis critico de la herramienta en función del tema seleccionado.</div>
#
# - <div style="text-align: justify;">Caso 1. La IA elegida por dos estudiantes que trabajaron separamente un mismo tema, les arrojo el mismo ppt con la misma información solo cambiando los colores.</div>
# - <div style="text-align: justify;">Caso 2. Dos grupos de estudiantes eligieron un mismo tema, en un caso le entregó la informaicón correcta  y en el otro alucino y entregó informacion errónea.</div>
# - <div style="text-align: justify;">Caso 3. La IA elegida no entregó ninguna información correcta al te,a solicitado</div>

# %% [markdown]
# ### 🤖 ¿Qué son estos "Grandes Modelos de Lenguaje"?
#
# <div style="text-align:justify;">Imagina que tienes un compañero de estudio que leyó millones de libros, artículos y páginas web, y ahora puede conversar contigo sobre cualquier tema. Eso es básicamente lo que son ChatGPT, Claude, Gemini y las otras herramientas de IA.</div>

# %% [markdown]
# ### **¿Cómo funcionan realmente?**
# 1. **Fueron entrenados** con textos de internet, libros y documentos (¡millones de ellos!).
# 2. **Aprendieron patrones** de cómo se escribe y se estructura la información.
# 3. **Generan respuestas** prediciendo qué palabras deberían venir después.
# 4. **NO tienen una base de datos** con hechos verificados como una enciclopedia **[Guía UNESCO sobre IA en Educación](https://www.unesco.org/es/digital-education/artificial-intelligence)**.
# 5. **NO pueden distinguir** automáticamente entre información real y falsa.

# %% [markdown]
# ### **Una analogía que te ayudará a entender:**
# Es como un compañero de clase muy inteligente que:
# - ✅ Leyó muchísimo y tiene muy buena memoria.
# - ✅ Es excelente explicando y conectando ideas.
# - ❌ A veces confunde detalles porque leyó demasiado.
# - ❌ No siempre recuerda de dónde sacó cada información.
# - ❌ Puede sonar muy seguro incluso cuando se equivoca.

# %% [markdown]
# ### **¿Por qué esto importa para tus tareas escolares?**
# **Son EXCELENTES para:**
# - 📖 Explicar conceptos complicados en palabras simples.
# - 🧠 Ayudarte a entender conexiones entre ideas.
# - ✏️ Mejorar la estructura de tus textos.
# - 💡 Darte ideas cuando no sabes por dónde empezar.
# - 🔄 Revisar y sugerir mejoras a lo que ya escribiste.

# %% [markdown]
# **Son TERRIBLES para:**
# - 📅 Darte fechas exactas sin verificar.
# - 👥 Recordar nombres específicos correctamente.
# - 📊 Proporcionar datos precisos (notas, fórmulas, estadísticas).
# - 📚 Citar fuentes reales (a veces las inventa).
# - 🎯 Hacer tu tarea por ti.

# %% [markdown]
# ### **La conclusión importante:**
# Estas herramientas son como **tutores muy inteligentes pero no infalibles**. Pueden ayudarte enormemente a aprender y mejorar tu trabajo, pero NUNCA debes confiar ciegamente en los datos específicos que te dan **[Guía para Estudiantes de IA 2025](https://studentguidetoai.org/obtenga-la-guia-para-estudiantes-de-inteligencia-artificial-2025/)**.

# %% [markdown]
# ### 📊 Comparación Rápida: ¿Cuál usar para qué? (Actualizada 2025)
#
# | Herramienta | ¿Para qué sirve mejor? | ¿Cuándo usarla? | ⚠️ **RIESGO PRINCIPAL** | **Novedad 2025** |
# |-------------|------------------------|------------------|------------------------|------------------|
# | **ChatGPT** | Explicar conceptos difíciles | Cuando no entiendes algo | **Inventa información falsa** | Soporte para "Deep Research" en búsquedas profundas |
# | **Claude** | Revisar y mejorar tus textos | Cuando ya escribiste algo | **Es muy cauteloso, a veces exagera** | Mejor en razonamiento ético, ideal para análisis complejos |
# | **Gemini** | Buscar información básica | Para verificar datos | **Privilegia fuentes en inglés** | Líder en matemáticas (86.7% AIME); integra con Google para multimedia |
# | **Perplexity** | Encontrar fuentes confiables | Para investigar en serio | **Solo muestra lo que está online** | Citas automáticas mejoradas para investigación académica |
# | **DeepSeek** | Analizar números y problemas lógicos | Para matemáticas y ciencias | **Ignora aspectos humanos/creativos** | Gratuito y top en lógica/código; sin límites de uso |
# | **Grok** | Ver debates actuales | Para temas controversiales | **Refleja opiniones de redes sociales** | 93.3% en exámenes matemáticos; fuerte en tendencias reales |

# %% [markdown]
# ### ⚖️ Las Reglas de Oro para Usar IA en Tareas Escolares

# %% [markdown]
# - **🔴 REGLA DE ORO: NUNCA copies y pegues directamente. Siempre verifica la información.** **[Toolkit TeachAI para Guías Éticas](https://www.teachai.org/toolkit)**.
# -  **Contrasta con fuentes confiables**: libros de texto, Enciclopedias (Britannica, Wikipedia como punto de partida), Sitios web educativos, tu calculadora en caso de caluclo matematicos.
# - Úsala para APRENDER, no para evitar aprender
# - Sé TRANSPARENTE con tus profesores, Mencionar cómo usaste IA como herramienta de apoyo
# - Desarrolla TU pensamiento crítico: Cuestionar, comparar y formar tu propia opinión
