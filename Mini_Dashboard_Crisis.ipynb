# %% [markdown]
# # Mini Dashboard de Crisis Históricas
#
# <div style="text-align: justify;">
# Ahora que conoces las fórmulas básicas de Google Sheets, es momento de ponerlas en práctica. En este capítulo crearás un <b>mini dashboard</b> que resume visualmente los datos más importantes del dataset de crisis históricas.
# </div>
#
# ```{admonition} 🎯 ¿Qué es un Dashboard?
# :class: tip
#
# Un **dashboard** (o tablero de control) es una visualización que muestra los indicadores más importantes de un conjunto de datos en un solo lugar. Es como el tablero de un auto: de un vistazo ves velocidad, combustible y temperatura sin tener que revisar cada sistema por separado.
# ```

# %% [markdown]
# ## 🎯 Objetivos de aprendizaje
#
# Al finalizar este capítulo serás capaz de:
#
# - ✅ Diseñar la estructura de un dashboard
# - ✅ Combinar múltiples fórmulas para obtener métricas
# - ✅ Aplicar formato condicional para visualizar datos
# - ✅ Crear gráficos básicos en Google Sheets
# - ✅ Comunicar información de forma clara y visual

# %% [markdown]
# ## 📊 Recordatorio: El Dataset
#
# Seguiremos trabajando con el dataset del **Seshat Databank** que contiene 169 crisis históricas de diferentes civilizaciones.
#
# ```{admonition} ⚠️ Cita Obligatoria
# :class: warning
#
# Esta investigación empleó datos del **Seshat Databank** ([seshatdatabank.info](https://seshatdatabank.info)) bajo la licencia Creative Commons Attribution Non-Commercial (CC By-NC SA).
#
# **Referencias:**
# - [Turchin et al., 2015](https://doi.org/10.21237/C7clio6127917) - *"Seshat: El banco de datos de la historia global"*. Cliodinámica 6(1): 77-107.
# - [Hoyer et al., 2023](https://doi.org/10.1098/rstb.2022.0402) - *"Navegando por la policrisis"*. Transacciones filosóficas de la Royal Society B.
# ```
#
# **Columnas clave que usaremos:**
#
# | Columna | Variable | Descripción |
# |---------|----------|-------------|
# | A | `Polity.Name` | Nombre de la sociedad |
# | G | `collapse` | ¿Hubo colapso? (0/1) |
# | H | `epidemic` | ¿Hubo epidemia? (0/1) |
# | L | `civil.war` | ¿Hubo guerra civil? (0/1) |
# | P | `conquest` | ¿Hubo conquista? (0/1) |
# | S | `Severity` | Índice de severidad (0-10) |

# %% [markdown]
# ## 📝 Paso 1: Crear una nueva hoja
#
# 1. Abre tu archivo de Google Sheets con los datos de crisis
# 2. En la parte inferior, haz clic en el **+** para agregar una nueva hoja
# 3. Haz doble clic en el nombre de la hoja y renómbrala como **"Dashboard"**
#
# ```{note}
# Mantener el dashboard en una hoja separada te permite tener los datos "crudos" en una hoja y el resumen visual en otra. Es una buena práctica de organización.
# ```

# %% [markdown]
# ## 📐 Paso 2: Diseñar la estructura
#
# Copia esta estructura en tu hoja **Dashboard**. Escribe exactamente lo que aparece en cada celda:
#
# ### Sección de título (fila 1)
#
# | Celda | Escribe esto |
# |-------|-------------|
# | A1 | `📊 DASHBOARD: Crisis Históricas` |
#
# ### Sección de estadísticas generales (filas 3-8)
#
# | Celda | Escribe esto |
# |-------|-------------|
# | A3 | `ESTADÍSTICAS GENERALES` |
# | A5 | `Total de crisis registradas` |
# | A6 | `Promedio de severidad` |
# | A7 | `Severidad máxima` |
# | A8 | `Severidad mínima` |
#
# ### Sección de análisis por tipo (filas 10-15)
#
# | Celda | Escribe esto |
# |-------|-------------|
# | A10 | `ANÁLISIS POR TIPO DE CRISIS` |
# | A12 | `Crisis con epidemia` |
# | A13 | `Crisis con guerra civil` |
# | A14 | `Crisis con colapso` |
# | A15 | `Crisis con conquista` |
#
# ### Sección de porcentajes (filas 17-22)
#
# | Celda | Escribe esto |
# |-------|-------------|
# | A17 | `PORCENTAJES` |
# | A19 | `% con epidemia` |
# | A20 | `% con guerra civil` |
# | A21 | `% con colapso` |
# | A22 | `% con conquista` |

# %% [markdown]
# ## 🔢 Paso 3: Agregar las fórmulas
#
# Ahora viene lo importante: agregar las fórmulas en la **columna B** que calcularán automáticamente los valores.
#
# ```{admonition} ⚠️ Importante: Nombre de la hoja de datos
# :class: warning
#
# En las fórmulas uso `Datos_Crisis!` como nombre de la hoja donde están los datos. Si tu hoja tiene otro nombre (por ejemplo `Hoja1`), debes cambiarlo en cada fórmula.
#
# Ejemplo: `=COUNTA(Hoja1!A2:A170)` en vez de `=COUNTA(Datos_Crisis!A2:A170)`
# ```

# %% [markdown]
# ### 📊 Fórmulas para Estadísticas Generales
#
# | Celda | Fórmula | Qué hace |
# |-------|---------|----------|
# | B5 | `=COUNTA(Datos_Crisis!A2:A170)` | Cuenta el total de crisis |
# | B6 | `=ROUND(AVERAGE(Datos_Crisis!S2:S170),2)` | Promedio redondeado a 2 decimales |
# | B7 | `=MAX(Datos_Crisis!S2:S170)` | El valor más alto de severidad |
# | B8 | `=MIN(Datos_Crisis!S2:S170)` | El valor más bajo de severidad |
#
# ```{tip}
# La función `ROUND(valor, decimales)` redondea un número. Usamos `ROUND(...,2)` para mostrar solo 2 decimales y que el dashboard se vea más limpio.
# ```

# %% [markdown]
# ### 📈 Fórmulas para Análisis por Tipo de Crisis
#
# | Celda | Fórmula | Qué hace |
# |-------|---------|----------|
# | B12 | `=COUNTIF(Datos_Crisis!H2:H170,1)` | Cuenta crisis con epidemia |
# | B13 | `=COUNTIF(Datos_Crisis!L2:L170,1)` | Cuenta crisis con guerra civil |
# | B14 | `=COUNTIF(Datos_Crisis!G2:G170,1)` | Cuenta crisis con colapso |
# | B15 | `=COUNTIF(Datos_Crisis!P2:P170,1)` | Cuenta crisis con conquista |
#
# ```{note}
# Recuerda que en el dataset, `1` significa "sí ocurrió" y `0` significa "no ocurrió". Por eso buscamos el valor `1`.
# ```

# %% [markdown]
# ### 📊 Fórmulas para Porcentajes
#
# | Celda | Fórmula | Qué hace |
# |-------|---------|----------|
# | B19 | `=ROUND(B12/B5*100,1)&"%"` | % de crisis con epidemia |
# | B20 | `=ROUND(B13/B5*100,1)&"%"` | % de crisis con guerra civil |
# | B21 | `=ROUND(B14/B5*100,1)&"%"` | % de crisis con colapso |
# | B22 | `=ROUND(B15/B5*100,1)&"%"` | % de crisis con conquista |
#
# ```{admonition} 💡 ¿Qué hace el símbolo `&`?
# :class: tip
#
# El símbolo `&` une (concatena) textos. En este caso:
# - `ROUND(B12/B5*100,1)` calcula el porcentaje (ejemplo: `30.8`)
# - `&"%"` le agrega el símbolo de porcentaje al final
# - Resultado: `30.8%`
# ```

# %% [markdown]
# ## 🎨 Paso 4: Aplicar formato visual básico
#
# Un buen dashboard no solo tiene datos correctos, también es **fácil de leer**. Aplica estos formatos:
#
# ### Título principal (A1)
# 1. Selecciona la celda A1
# 2. Pon el texto en **negrita** (Ctrl+B)
# 3. Aumenta el tamaño de fuente a **16 o 18**
# 4. Cambia el color de fondo a un azul oscuro
# 5. Cambia el color del texto a blanco
#
# ### Títulos de sección (A3, A10, A17)
# 1. Selecciona las celdas A3, A10 y A17
# 2. Pon el texto en **negrita**
# 3. Aplica un color de fondo gris claro
#
# ### Columna de valores (B)
# 1. Selecciona B5:B22
# 2. Alinea el texto a la **derecha**
# 3. Pon los números en **negrita**
#
# ### Ancho de columnas
# 1. Haz doble clic en el borde entre las columnas A y B para ajustar automáticamente
# 2. O arrastra para que la columna A tenga unos 250 píxeles de ancho

# %% [markdown]
# ## 🚦 Paso 5: Formato condicional (colores automáticos)
#
# El formato condicional cambia automáticamente el color de las celdas según su valor. Haremos que los porcentajes altos aparezcan en rojo (crisis frecuentes) y los bajos en verde (poco frecuentes).
#
# ### Configuración paso a paso:
#
# 1. Selecciona las celdas **B19:B22** (los porcentajes)
# 2. Ve a **Formato** → **Formato condicional**
# 3. Crea estas tres reglas:
#
# ```{admonition} Regla 1: Porcentaje alto (🔴 Rojo)
# :class: danger
#
# - **Aplicar a rango:** B19:B22
# - **Formato de celdas si:** Fórmula personalizada
# - **Fórmula:** `=VALUE(SUBSTITUTE(B19,"%",""))>40`
# - **Color de fondo:** Rojo claro
# ```
#
# ```{admonition} Regla 2: Porcentaje medio (🟡 Amarillo)
# :class: warning
#
# - **Aplicar a rango:** B19:B22
# - **Formato de celdas si:** Fórmula personalizada
# - **Fórmula:** `=AND(VALUE(SUBSTITUTE(B19,"%",""))>=20,VALUE(SUBSTITUTE(B19,"%",""))<=40)`
# - **Color de fondo:** Amarillo claro
# ```
#
# ```{admonition} Regla 3: Porcentaje bajo (🟢 Verde)
# :class: tip
#
# - **Aplicar a rango:** B19:B22
# - **Formato de celdas si:** Fórmula personalizada
# - **Fórmula:** `=VALUE(SUBSTITUTE(B19,"%",""))<20`
# - **Color de fondo:** Verde claro
# ```
#
# ```{note}
# **¿Por qué usamos `VALUE(SUBSTITUTE(...))`?**
#
# Porque nuestros porcentajes son texto ("30.8%"), no números. La fórmula:
# 1. `SUBSTITUTE(B19,"%","")` quita el símbolo % → "30.8"
# 2. `VALUE(...)` convierte el texto en número → 30.8
# 3. Ahora sí podemos comparar: `30.8 > 40` → Falso
# ```

# %% [markdown]
# ## 📊 Paso 6: Agregar un gráfico
#
# Un gráfico hace que los datos sean más fáciles de entender de un vistazo.
#
# ### Crear el gráfico:
#
# 1. Selecciona las celdas **A12:B15** (los tipos de crisis y sus cantidades)
# 2. Ve a **Insertar** → **Gráfico**
# 3. En el panel lateral, elige **Tipo de gráfico:** Gráfico de barras horizontal
# 4. En la pestaña **Personalizar**:
#    - **Título del gráfico:** "Tipos de Crisis Históricas"
#    - **Color de las barras:** Elige un color que combine con tu dashboard
#
# ### Alternativa: Gráfico circular
#
# Si prefieres ver las proporciones:
# 1. Selecciona **A12:B15**
# 2. Insertar → Gráfico → **Gráfico circular**
# 3. Activa la opción de mostrar porcentajes en las etiquetas
#
# ```{tip}
# Mueve el gráfico a la derecha de tu dashboard (columnas D-H) para que no tape las fórmulas.
# ```

# %% [markdown]
# ## ✅ Resultado esperado
#
# Tu dashboard debería verse similar a esto:
#
# ```
# ╔═══════════════════════════════════════════════════════════╗
# ║  📊 DASHBOARD: Crisis Históricas                          ║
# ╠═══════════════════════════════════════════════════════════╣
# ║                                                           ║
# ║  ESTADÍSTICAS GENERALES                                   ║
# ║  ─────────────────────────────────────────                ║
# ║  Total de crisis registradas          │  169              ║
# ║  Promedio de severidad                │  3.45             ║
# ║  Severidad máxima                     │  10               ║
# ║  Severidad mínima                     │  0                ║
# ║                                                           ║
# ║  ANÁLISIS POR TIPO DE CRISIS                              ║
# ║  ─────────────────────────────────────────                ║
# ║  Crisis con epidemia                  │  52               ║
# ║  Crisis con guerra civil              │  71               ║
# ║  Crisis con colapso                   │  34               ║
# ║  Crisis con conquista                 │  89               ║
# ║                                                           ║
# ║  PORCENTAJES                                              ║
# ║  ─────────────────────────────────────────                ║
# ║  % con epidemia                       │  30.8%  🟡        ║
# ║  % con guerra civil                   │  42.0%  🔴        ║
# ║  % con colapso                        │  20.1%  🟡        ║
# ║  % con conquista                      │  52.7%  🔴        ║
# ║                                                           ║
# ╚═══════════════════════════════════════════════════════════╝
# ```
#
# ```{admonition} 🤔 ¿Qué nos dicen estos datos?
# :class: seealso
#
# Mirando el dashboard podemos hacer observaciones históricas interesantes:
#
# - **La conquista externa** fue el tipo de crisis más común (52.7%)
# - **La guerra civil** también fue muy frecuente (42%)
# - **El colapso total** fue relativamente raro (20.1%)
# - Esto sugiere que las sociedades históricas resistían más a las amenazas internas que a las externas
# ```

# %% [markdown]
# ## 🚀 Extensión: Dashboard Avanzado
#
# Si terminaste y quieres ir más allá, agrega estas secciones adicionales:
#
# ### Top 5 crisis más severas
#
# Agrega en las celdas A24-A28:
#
# | Celda | Texto | Fórmula (columna B) |
# |-------|-------|--------------------|
# | A24 | `TOP 5 CRISIS MÁS SEVERAS` | |
# | A25 | `1° lugar` | `=LARGE(Datos_Crisis!S2:S170,1)` |
# | A26 | `2° lugar` | `=LARGE(Datos_Crisis!S2:S170,2)` |
# | A27 | `3° lugar` | `=LARGE(Datos_Crisis!S2:S170,3)` |
# | A28 | `4° lugar` | `=LARGE(Datos_Crisis!S2:S170,4)` |
# | A29 | `5° lugar` | `=LARGE(Datos_Crisis!S2:S170,5)` |
#
# ### Nombre de la crisis más severa
#
# Esta fórmula avanzada busca el nombre de la crisis con mayor severidad:
#
# ```
# =INDEX(Datos_Crisis!A2:A170,MATCH(MAX(Datos_Crisis!S2:S170),Datos_Crisis!S2:S170,0))
# ```
#
# ```{tip}
# **¿Cómo funciona INDEX+MATCH?**
#
# 1. `MAX(S2:S170)` encuentra el valor máximo de severidad (ej: 10)
# 2. `MATCH(...,S2:S170,0)` encuentra en qué fila está ese valor (ej: fila 45)
# 3. `INDEX(A2:A170,...)` devuelve el nombre que está en esa fila
#
# Es como decir: "Busca el 10 en la columna S, dime en qué fila está, y luego dime qué nombre hay en esa misma fila de la columna A"
# ```
#
# ### Comparativo: ¿Qué es más destructivo?
#
# | Celda | Texto | Fórmula |
# |-------|-------|--------|
# | A31 | `COMPARATIVO DE SEVERIDAD` | |
# | A32 | `Promedio CON epidemia` | `=ROUND(AVERAGEIF(Datos_Crisis!H2:H170,1,Datos_Crisis!S2:S170),2)` |
# | A33 | `Promedio SIN epidemia` | `=ROUND(AVERAGEIF(Datos_Crisis!H2:H170,0,Datos_Crisis!S2:S170),2)` |

# %% [markdown]
# ## ✏️ Ejercicios
#
# ```{admonition} Ejercicio 1: Amplía tu dashboard
# :class: note
#
# Agrega una nueva sección que muestre:
# - Cantidad de crisis con **fragmentación territorial**
# - Cantidad de crisis con **asesinato de líder**
# - Sus respectivos porcentajes
#
# Pista: fragmentación está en columna N, asesinato en columna Q.
# ```
#
# ```{admonition} Ejercicio 2: Nuevo gráfico
# :class: note
#
# Crea un segundo gráfico que compare:
# - Promedio de severidad CON colapso vs SIN colapso
# - Usa `AVERAGEIF` para calcular ambos valores
# - Elige un gráfico de barras para la comparación
# ```
#
# ```{admonition} Ejercicio 3: Formato condicional extra
# :class: note
#
# Aplica formato condicional a la celda de "Severidad máxima" (B7):
# - Si es mayor a 8: fondo rojo
# - Si está entre 5 y 8: fondo amarillo
# - Si es menor a 5: fondo verde
# ```

# %% [markdown]
# ## 🏆 Desafío Final: Tu pregunta histórica
#
# Elige **UNA** de estas preguntas y respóndela agregando nuevas métricas a tu dashboard:
#
# ```{admonition} Preguntas de investigación
# :class: seealso
#
# 1. **¿Las epidemias causan colapsos?**
#    - Cuenta cuántas crisis tienen AMBAS: epidemia Y colapso
#    - Pista: `=COUNTIFS(H2:H170,1,G2:G170,1)`
#
# 2. **¿Las guerras civiles son más destructivas que las conquistas?**
#    - Compara el promedio de severidad de cada tipo
#    - Muestra ambos en tu dashboard
#
# 3. **¿Cuántas crisis "perfectas" existen?**
#    - Una crisis "perfecta" tiene TODO: epidemia, guerra civil, colapso Y conquista
#    - Pista: `=COUNTIFS(H2:H170,1,L2:L170,1,G2:G170,1,P2:P170,1)`
# ```
#
# **Entrega:** Captura de pantalla de tu dashboard completo con la nueva métrica y una breve interpretación (2-3 oraciones) de lo que encontraste.

# %% [markdown]
# ```{admonition} 💡 Recuerda
# :class: tip
#
# - 🎨 Un buen dashboard es **claro y fácil de leer**
# - 🔢 Las fórmulas deben **actualizarse automáticamente** si cambian los datos
# - 🚦 El formato condicional ayuda a **identificar patrones** rápidamente
# - 📊 Los gráficos **complementan** los números, no los reemplazan
# - 🤔 Lo más importante es **qué historia cuentan los datos**
# ```
